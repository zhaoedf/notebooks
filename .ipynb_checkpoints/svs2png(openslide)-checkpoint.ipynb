# %%
import openslide
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
slide = openslide.OpenSlide('/data/defeng/stomach_svs/EBV/678675.svs')

# %%
type(slide)
# Out:
# openslide.OpenSlide

# %%
print(f'dimension: {slide.dimensions}')
print('-'*50)
print(f'got *{slide.level_count}* levels, each dimensions are:')
for idx, (width,height) in enumerate(slide.level_dimensions):
    print(f'{width}, {height}, downsample_factor:{slide.level_downsamples[idx]}')
# Out:
# dimension: (159360, 75519)
# --------------------------------------------------
# got *4* levels, each dimensions are:
# 159360, 75519, downsample_factor:1.0
# 39840, 18879, downsample_factor:4.000079453360877
# 9960, 4719, downsample_factor:16.00158931977114
# 2490, 1179, downsample_factor:64.02671755725191

# %%
full_img = np.array(slide.read_region((0,0), level=3, size=(2490,1179)))
# 4 levels, so the maximum level is 3.

# %%
plt.imshow(full_img)

# %%
thumbnail = np.array(slide.get_thumbnail((512,512)))
thumbnail.shape # 1179/242 ≈ 2490/512
# Out:
# (242, 512, 3)

# %%
plt.imshow(thumbnail)

# %%
associated_img = slide.associated_images

# %%
type(associated_img)
# Out:
# openslide._AssociatedImageMap

# %%
associated_img._keys()
# Out:
# ['label', 'macro', 'thumbnail']

# %%
tn_img = associated_img['thumbnail']
plt.imshow(tn_img)

# %%
# tn_img.convert('RGB')
tn_img = np.array(tn_img)
tn_img = cv2.cvtColor(tn_img, cv2.COLOR_RGB2BGR)

# %%
tn_img.shape
# Out:
# (485, 1024, 4)

# %%
import cv2
tn_img = tn_img[:,:,:3]
tn_img_resized = cv2.resize(tn_img,(512,512))

# %%
tn_img_resized.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(tn_img_resized)
