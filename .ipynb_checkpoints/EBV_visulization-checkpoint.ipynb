# %%
import os
import cv2
import matplotlib.pyplot as plt
import glob

# %%
root_dir = '/data/defeng/luojing/datasets/'

# %%
# img_paths = glob.glob(os.path.join(root_dir,'imgs','*','*.png'))
img_paths = glob.glob(os.path.join(root_dir,'imgs','*.png'))
img_paths.sort()
img_paths[:5]
# Out:
# ['/data/defeng/luojing/datasets/imgs/0.png',
#  '/data/defeng/luojing/datasets/imgs/1.png',
#  '/data/defeng/luojing/datasets/imgs/10.png',
#  '/data/defeng/luojing/datasets/imgs/100.png',
#  '/data/defeng/luojing/datasets/imgs/1000.png']

# %% [markdown]
# ## 可视化

# %%
index=15

# %%
def get_corresponding_mask_path(img_path):
    temp = img_path.split('/')
    img_name = temp[-1][:-4]
    temp[-2] = 'masks'
    temp[-1] = img_name+'_mask'+'.png'
    
    return '/'.join(temp)

# %%
img = cv2.imread(img_paths[index])
mask = cv2.imread(get_corresponding_mask_path(img_paths[index]))

# %%
from PIL import Image
test = Image.open(get_corresponding_mask_path(img_paths[index])).convert('L')

# %%
mask_gray = cv2.cvtColor(mask,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img)

# %%
plt.imshow(mask)

# %%
plt.imshow(mask_gray, cmap='gray')

# %%
fusion_img = cv2.addWeighted(img,0.8,mask,0.15,0)
plt.imshow(fusion_img)

# %%
w=10
h=10

rows=1
cols=2

img_seq = [img, fusion_img]
name_seq = ['original', 'fusion']

fig=plt.figure()
figu,ax = plt.subplots(rows,cols,figsize=[8,8])
for i in range(rows*cols):
    # ind = start_with + i*show_every
    ax[int(i/rows)].set_title(name_seq[i])
    ax[int(i/rows)].imshow(img_seq[i],cmap='jet')
    ax[int(i/rows)].axis('off')
plt.show()


# for i in range(num):
#     fig, ax = plt.subplot(1,num,i+1) 
    
#     plt.axis('off')
#     plt.tight_layout()
#     ax.set_title(name_seq[i])
    
#     plt.imshow(img_seq[i])

# %%
def vis(img1,img2):
    import numpy as np
    import matplotlib.pyplot as plt

    my_image1 = img1
    my_image2 = img2

    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=[10,10])

    axes[0].set_title('original img')
    axes[0].axis('off')
    axes[1].set_title('probs')
    axes[1].axis('off')

    im1 = axes[0].imshow(my_image1)
    clim=im1.properties()['clim']
    # im2 = axes[1].imshow(my_image2, clim=clim)
    im2 = axes[1].imshow(my_image2,cmap='magma')

    fig.colorbar(im2, ax=axes.ravel().tolist(), shrink=0.5)

    plt.show()
    plt.savefig('./vis_result.png')

# %%
vis(fusion_img,data2)

# %%
i=20
t_img_path = './test_imgs/'
t_preds_path = './test_result/exp0/'
t_masks_path = 'test_masks/'

t_imgs = os.listdir(t_img_path)
t_preds = glob.glob(os.path.join(t_preds_path,'*.npy'))
t_masks = glob.glob(os.path.join(t_masks_path,'*.png'))

t_img = cv2.imread(os.path.join(t_img_path, t_imgs[i]))
t_img_name = t_imgs[i][:-4]

t_mask = cv2.imread(os.path.join(t_masks_path, t_img_name+'_mask'+'.png'), 0)
t_pred = np.load(os.path.join(t_preds_path, 'test_'+t_img_name+'.npy'))

# %%
t_fusion_img = cv2.addWeighted(t_img,0.7,cv2.cvtColor(t_mask,cv2.COLOR_GRAY2BGR),0.25,2)
vis(t_fusion_img, t_pred)

# %%
len(img_paths), len(mask_paths)
# Out:
# (1006, 1006)

# %% [markdown]
# ## create test dataset

# %%
root_dir = '/data/defeng/backup6-tranfer-UNet/data'
img_paths = glob.glob(os.path.join(root_dir,'imgs','*.png'))

if os.path.exists(os.path.join(root_dir,'test_imgs')):
    shutil.rmtree(os.path.join(root_dir,'test_imgs'), ignore_errors=True)
os.makedirs(os.path.join(root_dir,'test_imgs'))

if os.path.exists(os.path.join(root_dir,'test_masks')):
    shutil.rmtree(os.path.join(root_dir,'test_masks'), ignore_errors=True)
os.makedirs(os.path.join(root_dir,'test_masks'))

# %%
percent = 0.15
test_size = int(len(img_paths)*percent)

# %%
import numpy as np
test_indexs = np.random.choice(list(range(len(img_paths))), size=test_size, replace=False, p=None)
test_indexs[:5]
# Out:
# array([271, 121,  11, 259, 698])

# %%
import shutil

for idx in test_indexs:
    img_path = img_paths[idx]
    mask_path = get_corresponding_mask_path(img_path)
    print(img_path)
    
    temp = img_path.split('/')
    temp[-2] = 'test_imgs'
    new_img_path = '/'.join(temp)
    temp = mask_path.split('/')
    temp[-2] = 'test_masks'
    new_mask_path = '/'.join(temp)
    
    shutil.move(img_path, new_img_path)
    shutil.move(mask_path, new_mask_path)
# Out:
# /data/defeng/backup6-tranfer-UNet/data/imgs/673.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/41.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/446.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/292.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/573.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/409.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/477.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/772.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/570.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/581.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/26.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/977.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/810.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/517.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/81.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/330.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/194.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/43.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/463.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/279.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/324.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/384.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/742.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/248.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/73.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/235.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/997.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/168.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/952.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/622.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/343.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/239.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/56.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/412.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/202.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/295.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/824.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/423.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/49.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/246.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/707.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/726.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/390.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/497.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/652.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/649.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/856.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/296.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/62.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/91.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/234.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/532.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/737.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/980.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/134.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/892.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/300.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/3.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/386.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/270.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/417.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/466.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/28.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/765.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/868.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/371.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/117.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/695.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/850.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/650.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/656.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/206.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/376.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/53.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/874.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/20.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/275.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/884.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/584.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/962.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/916.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/320.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/311.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/777.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/940.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/971.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/992.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/692.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/308.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/45.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/544.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/645.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/363.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/534.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/403.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/664.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/217.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/400.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/835.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/491.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/866.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/616.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/456.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/1003.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/954.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/836.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/503.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/266.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/388.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/195.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/115.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/804.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/930.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/794.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/284.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/855.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/473.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/397.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/79.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/939.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/431.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/785.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/858.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/931.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/485.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/825.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/107.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/418.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/119.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/903.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/30.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/621.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/750.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/323.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/495.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/182.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/716.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/591.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/40.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/778.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/928.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/956.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/178.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/391.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/847.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/126.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/721.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/554.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/340.png
# /data/defeng/backup6-tranfer-UNet/data/imgs/508.png

# %%
len(glob.glob(os.path.join(root_dir, 'test_imgs','*'))), len(test_indexs)
# Out:
# (150, 150)

# %%
len(glob.glob(os.path.join(root_dir, 'imgs','*'))), len(test_indexs)
# Out:
# (856, 150)
